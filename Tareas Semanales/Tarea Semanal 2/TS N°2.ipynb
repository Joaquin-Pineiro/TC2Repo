# %% [markdown]
# # Tarea Semanal 2

# %% [markdown]
# ## Transferencia
#
# $T(s) = -\frac{R3}{R1}\frac{ \frac{1}{C^2 R3^2}}{s^2+s \frac{1}{C R2}+\frac{1}{C^2 R3^2}}$
#
# $Q = \frac{R2}{R3} = 3$
#
# $W_O = \frac{1}{C R3} = 1$
#
# ### Simulacion de Amplitud y fase
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Transferencia Normalizada
#
#
# $T(s) = -\frac{1}{R1'}\frac{1}{s^2+s \frac{1}{R2'}+1}$
#
# $\Omega_w = \frac{1}{C R3}$
#
# $\Omega_z = R3$
#
#
# $R1' = \frac{R1}{R3} = 0.1$
#
# $R2' = \frac{R2}{R3} = 3$
#
# $R3' = \frac{R3}{R3} = 1$
#
# $R4' = \frac{R4}{R3} = 0.1$
#
# $C'' = \frac{1}{\frac{R3}{R3}} = 1$
# ### Simulacion de Amplitud y fase
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Transferencia Butterworth
# $T(s) = -\frac{R3}{R1}\frac{ \frac{1}{C^2 R3^2}}{s^2+s \sqrt{2}+\frac{1}{C^2 R3^2}}$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Transferencia Pasabanda
#
# $T(s) = -\frac{R2}{R1}\frac{ \frac{s}{C R2}}{s^2+s \frac{1}{C R2}+\frac{1}{C^2 R3^2}}$
#
# $|T(W_o)| = \frac{R2 R3 C}{R1} = 30$
#
# $B = \frac{W_o}{Q} = \sqrt{2}$
#
# ### Simulacion de Amplitud y fase
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np

import matplotlib.pyplot as plt

from scipy import signal as sig
from splane import pzmap, bodePlot, pretty_print_bicuad_omegayq


C = 10e-6
R1=10e3
R2 = 300e3
R3 = 100e3

w0 = 1/(C*R3)


num = np.array([-R3/R1  * w0**2])
den = np.array([1,1/(C*R2),w0**2])



T = sig.TransferFunction(num , den)


plt.close('all')

pretty_print_bicuad_omegayq(num, den, displaystr = True)

bodePlot(T,[-2,2],[30,-10], 'none', 'none', 'Filtro Pasa Bajos', 1000 )
pzmap(T,True, 'Filtro Pasa Bajos', 'none', 'none')

##TRANSFERENCIA NORMALIZADA
Omega_z=R3
Omega_w=w0
R1_n=R1/Omega_z
R2_n = R2/Omega_z
R3_n=R3/Omega_z
C_n=C*Omega_z*Omega_w



num_n = np.array([-1/R1_n])
den_n = np.array([1,1/(R2_n),1])

T_n = sig.TransferFunction(num_n , den_n)


pretty_print_bicuad_omegayq(num_n, den_n, displaystr = True)


bodePlot(T,[-2,2],[30,-10], 'none', 'none', 'Filtro Pasa Bajos', 1000 )
pzmap(T_n,True, 'Filtro Pasa Todo Normalizado', 'none', 'none')


##TRANSFERENCIA Butterworth con epsilon=1 (WB = W0)

R2=70e3
num_b = np.array([-R3/R1  * w0**2])
den_b = np.array([1,1/(C*R2),w0**2])



T_b = sig.TransferFunction(num_b , den_b)

pretty_print_bicuad_omegayq(num_b, den_b, displaystr = True)

bodePlot(T_b,[-2,2],[30,-10], 'none', 'none', 'Filtro Pasa Bajos ButterWorth', 1000 )
pzmap(T_b,True, 'Filtro Pasa Todo ButterWorth', 'none', 'none')
# Out:
# $\displaystyle \frac{-10 }{s^2 + s \frac{  1}{  3} +   1^2}$
# $\displaystyle \frac{-10 }{s^2 + s \frac{  1}{  3} +   1^2}$
# $\displaystyle \frac{-10 }{s^2 + s \frac{  1}{0.7} +   1^2}$
# (6, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)
