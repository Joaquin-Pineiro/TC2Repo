# %% [markdown]
# # Tarea Semanal 5
#
# ## Ejercicio 3
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ### Se corroboran los $\frac{\pi}{2} rad$  en  $\omega = 0\frac{rad}{s}$ y $\frac{-\pi}{2} rad$  en  $\omega -> +\infty \frac{rad}{s}$
