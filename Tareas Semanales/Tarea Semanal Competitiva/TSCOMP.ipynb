# %% [markdown]
# # Tarea Semanal Competitiva

# %% [markdown]
# ## Analitico
# ![Tarea%20Semanal%20Competitiva_1.jpg](attachment:Tarea%20Semanal%20Competitiva_1.jpg)

# %% [markdown]
# ![Tarea%20Semanal%20Competitiva_2.jpg](attachment:Tarea%20Semanal%20Competitiva_2.jpg)

# %% [markdown]
# ![Tarea%20Semanal%20Competitiva_3.jpg](attachment:Tarea%20Semanal%20Competitiva_3.jpg)

# %% [markdown]
# ![Tarea%20Semanal%20Competitiva_4.jpg](attachment:Tarea%20Semanal%20Competitiva_4.jpg)

# %% [markdown]
# ![Tarea%20Semanal%20Competitiva_5.jpg](attachment:Tarea%20Semanal%20Competitiva_5.jpg)

# %% [markdown]
# ## Circuito
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Simulacion $Z21 = \frac{V2}{I1}$
# ![image.png](attachment:image.png)
