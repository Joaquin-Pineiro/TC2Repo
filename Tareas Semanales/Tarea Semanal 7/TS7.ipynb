# %% [markdown]
# # Tarea Semanal 7

# %% [markdown]
# ## Analitico
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ## Simulacion
#
#
# ### $Z_{11} = \frac{V_1}{I_1}| I2 = 0$
#
# ![image-4.png](attachment:image-4.png)
# ![image-3.png](attachment:image-3.png)
#
# ### La impedancia $Z_{11}$ vale 0.3 ohms y el desfasaje vale 0°
#
# ### $Z_{21} = \frac{V_2}{I_1}| I2 = 0$
#
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ### La impedancia $Z_{21}$ vale 0.3 ohms y el desfasaje vale 180°
#
# ### $Z_{12} = \frac{V_1}{I_2}| I1 = 0$
#
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ### La impedancia $Z_{12}$ vale 0.3 ohms y el desfasaje vale 180°
#
# ### $Z_{22} = \frac{V_2}{I_2}| I1 = 0$
#
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ### La impedancia $Z_{22}$ vale 0.3 ohms y el desfasaje vale 0°
#
#
# ### Por lo que verifica la matriz impedancia calculada analiticamente
