# %% [markdown]
# # Trabajo Practico Laboratorio 1
#
# ## Analítico
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ## Simulacion
#
# ## Implementacion Inversora del KHN
# ### Se utiliza el KHN inversor ya que para sumar la salida LP y HP se utiliza un sumador inversor
# ![image-5.png](attachment:image-5.png)
#
# ![image-4.png](attachment:image-4.png)
#
# Como se observa en la figura la aguja se encuentra en 50Hz y tanto el Q del HP como del LP valen -3dB $(Q = \frac{1}{\sqrt{2}})$ obteniendose un ancho de banda de 3dB
